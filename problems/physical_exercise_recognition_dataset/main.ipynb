# %% [markdown]
# https://www.kaggle.com/datasets/muhannadtuameh/exercise-recognition/code

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    pose_id                pose     x_nose     y_nose     z_nose  \
# 0        0           squats_up  -0.382815 -48.231250 -54.405792
# 1        1          situp_down  54.146880 -12.822491   5.564175
# 2        2          situp_down   9.891440 -54.147266  85.344970
# 3        3    jumping_jacks_up   0.904673 -51.350130 -33.606970
# 4        4  jumping_jacks_down  -3.153129 -55.255062 -17.745928
#
#    x_left_eye_inner  y_left_eye_inner  z_left_eye_inner  x_left_eye  \
# 0          0.137189        -50.040543        -51.997875    0.502047
# 1         56.762527        -11.221117         -0.363063   56.795986
# 2         12.784414        -55.229970         88.534775   14.006874
# 3          1.338871        -53.172337        -30.013737    1.743913
# 4         -2.046205        -57.477790        -18.198952   -1.506304
#
#    y_left_eye  ...  z_left_heel  x_right_heel  y_right_heel  z_right_heel  \
# 0  -50.058890  ...    33.283375    -12.302963     52.377000     21.567219
# 1  -10.608183  ...    -8.073100    -37.519974      4.045297     62.104233
# 2  -54.291880  ...  -132.024460    -61.214890     53.040688    -16.786700
# 3  -53.050697  ...    51.615970    -15.543400     38.251835     34.033176
# 4  -57.428230  ...    -2.849554      2.811829     56.000500     56.605590
#
#    x_left_foot_index  y_left_foot_index  z_left_foot_index  \
# 0          16.609533          54.351162          15.890617
# 1         -60.468560           6.281939          -8.185631
# 2          -5.844672          99.829030        -166.543060
# 3          16.610210          46.572014          38.680614
# 4           0.566345          66.231050         -19.252045
#
#    x_right_foot_index  y_right_foot_index  z_right_foot_index
# 0          -16.779694           55.382572            2.050140
# 1          -52.589350           -3.852214           59.750070
# 2          -73.826830           38.470097          -40.519830
# 3          -18.784650           45.098710           20.343110
# 4           -3.451297           60.029484           45.503677
#
# [5 rows x 101 columns]

# %%
data.isnull().sum()
# Out:
# pose_id               0
# pose                  0
# x_nose                0
# y_nose                0
# z_nose                0
#                      ..
# y_left_foot_index     0
# z_left_foot_index     0
# x_right_foot_index    0
# y_right_foot_index    0
# z_right_foot_index    0
# Length: 101, dtype: int64

# %%
train, test = train_test_split(data, test_size=0.4)

y_train = train['pose']
X_train = train.drop(['pose_id', 'pose'], axis=1)

y_test = test['pose']
X_test = test.drop(['pose_id', 'pose'], axis=1)

# %%
train.head()
# Out:
#      pose_id              pose     x_nose     y_nose     z_nose  \
# 597      597         squats_up  -1.496138 -48.741264  68.269066
# 744      744        situp_down   4.300380 -53.686108  85.444890
# 402      402  jumping_jacks_up -14.303438 -42.689710 -33.211895
# 572      572         squats_up   0.166678 -54.696762 -27.995596
# 71        71          situp_up   0.030425 -48.345417  12.583751
#
#      x_left_eye_inner  y_left_eye_inner  z_left_eye_inner  x_left_eye  \
# 597         -2.281564        -49.926884         63.151497   -2.730961
# 744          6.104891        -54.518574         95.140015    6.934241
# 402        -14.866879        -46.398937        -35.877193  -14.678796
# 572          0.751663        -56.650673        -24.547325    1.206568
# 71          -0.300587        -52.311230         14.489397   -0.539496
#
#      y_left_eye  ...  z_left_heel  x_right_heel  y_right_heel  z_right_heel  \
# 597  -49.903336  ...   -26.222055      8.040923     64.193640     -6.506496
# 744  -54.120690  ...   -96.244640    -16.767912     -3.181614    -89.174770
# 402  -47.232475  ...   -14.524986    -11.694265     55.786030     74.333370
# 572  -56.559340  ...    -3.496230     -9.399580     57.129520     14.760534
# 71   -52.436455  ...   -11.936620     34.994812     12.229238    -86.522675
#
#      x_left_foot_index  y_left_foot_index  z_left_foot_index  \
# 597         -12.713827          63.845080         -31.573868
# 744          -0.682879         -16.056858        -107.309250
# 402          14.499134          64.844124         -33.652695
# 572           4.090156          67.829570         -25.035671
# 71           40.499664          -2.478224         -26.969818
#
#      x_right_foot_index  y_right_foot_index  z_right_foot_index
# 597            9.051612           63.213580           -9.696036
# 744          -16.864443          -21.159086         -104.259490
# 402          -14.242885           60.566820           66.646890
# 572          -14.882117           59.467484           -1.899261
# 71            43.425570            0.145945         -102.542854
#
# [5 rows x 101 columns]

# %%
y_train.head()
# Out:
# 597           squats_up
# 744          situp_down
# 402    jumping_jacks_up
# 572           squats_up
# 71             situp_up
# Name: pose, dtype: object

# %%
rf_Model = RandomForestClassifier()

# %%
rf_Model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print(f'Accuracy: {rf_Model.score(X_test,y_test)}')
# Out:
# Accuracy: 0.8428246013667426
